# %% [raw]
# '''SUMMARY
# 1.Libraries Used:
#     pandas, numpy, matplotlib.pyplot, seaborn
#
# 2.Data Loading:
#     Loaded train.csv using pd.read_csv().
#
# 3.Basic EDA Operations:
#     Used .info(), .isnull().sum(), .describe(), .duplicated(), .head() to explore data structure, missing values, basic statistics, and duplicates.
#
# 4.Categorical Analysis with .value_counts() and countplot():
#     Sex vs Survival: Females had a higher survival rate than males.
#     Gender vs Class: Most males and females were in 3rd class.
#     Gender vs Embarkation: Most passengers embarked from port 'S' (Southampton).
#     Survival vs Class: 1st class passengers had a higher survival rate.
#     Survival vs Embarkation: Those who embarked from 'S' had higher survival.
#
# 5.Numerical Analysis:
#     Age Distribution: Used histplot(), showing most passengers were aged between 20–40 years.
#     Fare Distribution: Plotted Fare distribution revealing a few passengers with very high fares.
#
# 6.Relationship Analysis:
#     Pairplot: Used .pairplot() to visually explore the relationships between multiple variables (Survived, Age, Fare, Pclass).
#
#
# Survival was influenced by gender, class, and embarkation port.
# Females, younger people, and richer (1st class) passengers had higher survival chances.
# '''

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

# %%
#import dataset
df = pd.read_csv("train.csv")

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
#Checking for null values
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
#Checking for duplicate data
df.duplicated().sum()
# Out:
# 0

# %%
#displays rows with null values
df[df.isnull().any(axis=1)]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 0              1         0       3                   Braund, Mr. Owen Harris
# 2              3         1       3                    Heikkinen, Miss. Laina
# 4              5         0       3                  Allen, Mr. William Henry
# 5              6         0       3                          Moran, Mr. James
# 7              8         0       3            Palsson, Master. Gosta Leonard
# ..           ...       ...     ...                                       ...
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 890          891         0       3                       Dooley, Mr. Patrick
#
# ...

# %%
#converting column names into lower cases, so need not to worry about case sensitivity
df.columns=df.columns.str.strip().str.lower()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   passengerid  891 non-null    int64
#  1   survived     891 non-null    int64
#  2   pclass       891 non-null    int64
#  3   name         891 non-null    object
#  4   sex          891 non-null    object
#  5   age          714 non-null    float64
#  6   sibsp        891 non-null    int64
#  7   parch        891 non-null    int64
#  8   ticket       891 non-null    object
#  9   fare         891 non-null    float64
#  10  cabin        204 non-null    object
#  11  embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.head()
# Out:
#    passengerid  survived  pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 name     sex   age  sibsp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    parch            ticket     fare cabin embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
#Standardizing name column
#print("before cleaning")
#print(df.name.unique())
df.name= df.name.str.lower()
#print("after cleaning")
#print(df.name.unique())

# %%
df.head()
# Out:
#    passengerid  survived  pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 name     sex   age  sibsp  \
# 0                            braund, mr. owen harris    male  22.0      1
# 1  cumings, mrs. john bradley (florence briggs th...  female  38.0      1
# 2                             heikkinen, miss. laina  female  26.0      0
# 3       futrelle, mrs. jacques heath (lily may peel)  female  35.0      1
# 4                           allen, mr. william henry    male  35.0      0
#
#    parch            ticket     fare cabin embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
#Filling null values with 0
df.isnull().sum()
df.age=df.age.fillna(0)
df.cabin=df.cabin.fillna(0)
df.embarked=df.embarked.fillna(0)
df.isnull().sum()
# Out:
# passengerid    0
# survived       0
# pclass         0
# name           0
# sex            0
# age            0
# sibsp          0
# parch          0
# ticket         0
# fare           0
# cabin          0
# embarked       0
# dtype: int64

# %%
df.head()
# Out:
#    passengerid  survived  pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 name     sex   age  sibsp  \
# 0                            braund, mr. owen harris    male  22.0      1
# 1  cumings, mrs. john bradley (florence briggs th...  female  38.0      1
# 2                             heikkinen, miss. laina  female  26.0      0
# 3       futrelle, mrs. jacques heath (lily may peel)  female  35.0      1
# 4                           allen, mr. william henry    male  35.0      0
#
#    parch            ticket     fare cabin embarked
# 0      0         A/5 21171   7.2500     0        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250     0        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500     0        S

# %%
#Returns the count of different values in specific column
df.sex.value_counts()
# Out:
# sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
#Display the count of different values in specific column
sb.countplot(x='sex',data=df)
plt.title("Sex")
plt.show()
# The below plot clearly shows that the count of male is more compared to female

# %%
df.survived.value_counts()
#0=no, 1=yes
# Out:
# survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
df.survived.value_counts()
sb.countplot(x='survived', data=df)
plt.title('Survival Count')
plt.show()
#The below plot shows that survival rate is less

# %%
df.pclass.value_counts()
# Out:
# pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
sb.countplot(x='pclass',data=df)
plt.title("class travelling")
plt.show()
#Those who travelled in class are more compared to the other two classes

# %%
df.embarked.value_counts()
# Out:
# embarked
# S    644
# C    168
# Q     77
# 0      2
# Name: count, dtype: int64

# %%
sb.countplot(x='embarked',data=df)
plt.title("embarked")
plt.show()
#Port of Embarkation in high for Southampton than other two

# %%
#comparing survival based on sex
sb.countplot(x='sex', hue='survived', data=df)
plt.title("survival based on sex")
plt.show()
# Below plot shows that the female survival count is more compared to male

# %%
sb.countplot(x='sex',hue='pclass',data=df)
plt.title("gender based on class")
plt.show()
#Male and female population is more in class that other two classes

# %%
sb.countplot(x='sex',hue='embarked',data=df)
plt.title("gender based on embark")
plt.show()
# Below plot shows number male and of embarkment from the 3 different places

# %%
sb.countplot(x='survived',hue='pclass',data=df)
plt.title("Survival based on class")
plt.show()
#below plot shows the number of survival and those not survived. It clearly shows that the survivers are less and 
#among those who survived are more from pclass 1 than other 2

# %%
sb.countplot(x='survived',hue='embarked',data=df)
plt.title("Survival based on embark")
plt.show()
#Below plot shows the number of survival and those not survived. It clearly shows that the survivers are less and 
#among those who survived are embarked from S

# %%
sb.countplot(x='pclass',hue='embarked',data=df)
plt.title("Class vs embark")
plt.show()

# %%
sb.histplot(df.age.dropna(), kde=True)
plt.title('Age Distribution')
plt.show()

# %%
sb.histplot(df.fare.dropna(), kde=True)
plt.title('Fare')
plt.show()

# %%
sb.boxplot(x='survived', y='age', data=df)
plt.title('Age vs Survival')
plt.show()

# %%
sb.pairplot(df.dropna(), hue='survived')
plt.show()
